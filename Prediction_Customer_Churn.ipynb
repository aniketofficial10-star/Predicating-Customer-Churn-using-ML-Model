# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score,confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
#load csv

customers = pd.read_csv("Customers.csv")
churn = pd.read_csv("Churn.csv")
subscriptions = pd.read_csv("Subscriptions.csv")
transactions = pd.read_csv("Transactions.csv")

# %%
#merge: cust left join subscription

df = customers.merge(subscriptions, on = "CustomerID", how = "left")

# %%
df.head(4)
# Out:
#    CustomerID FirstName LastName                   Email   PhoneNumber  \
# 0           1      John      Doe    john.doe@example.com  123-456-7890
# 1           1      John      Doe    john.doe@example.com  123-456-7890
# 2           1      John      Doe    john.doe@example.com  123-456-7890
# 3           2      Jane    Smith  jane.smith@example.com  098-765-4321
#
#      JoinDate    Status         Region  SubscriptionID   StartDate  \
# 0  10-01-2022    Active  North America             1.0  10-01-2022
# 1  10-01-2022    Active  North America            44.0  10-01-2023
# 2  10-01-2022    Active  North America           101.0  01-07-2023
# 3  15-12-2021  Inactive         Europe             2.0  15-12-2021
#
#       EndDate PlanType
# 0  09-01-2023   Annual
# 1  09-01-2024  Monthly
# 2  30-06-2024  Monthly
# 3  14-12-2022  Monthly

# %%
transactions.head(3)
# Out:
#    TransactionID  CustomerID TransactionDate  Amount TransactionType
# 0              1          15      01-01-2024      32        Purchase
# 1              2          22      02-01-2024      52          Refund
# 2              3          43      03-01-2024     165        Purchase

# %%
#Prepare tranasaction summary for customer
#spend logic => for each cust Sum(purchase)-Sum(refund)

transactions["AdjustedAmount"] = transactions.apply(lambda row: -row["Amount"] if row["TransactionType"] == "Refund" else row["Amount"], axis=1)

# THis also works::: transactions["test"] = np.where(transactions["TransactionType"] == "Refund", -transactions["Amount"], transactions["Amount"])
transactions.head(3)
# Out:
#    TransactionID  CustomerID TransactionDate  Amount TransactionType  \
# 0              1          15      01-01-2024      32        Purchase
# 1              2          22      02-01-2024      52          Refund
# 2              3          43      03-01-2024     165        Purchase
#
#    AdjustedAmount
# 0              32
# 1             -52
# 2             165

# %%
transaction_summary =  transactions.groupby("CustomerID")["AdjustedAmount"].sum().reset_index().rename(columns = {"AdjustedAmount":"CustomerLifetime"})

# %%
transaction_summary.head(20)
# Out:
#     CustomerID  CustomerLifetime
# 0           11               195
# 1           15                32
# 2           17               -73
# 3           19              -140
# 4           21               -32
# 5           22               -52
# 6           23               196
# 7           25              -122
# 8           26               -20
# 9           28              -153
# 10          29               200
# 11          31               -66
# 12          33              -156
# 13          34               158
# 14          35              -145
# 15          37               143
# 16          39               120
# 17          40              -200
# 18          43               165
# 19          45               -69

# %%
#merge the transaction summary with the df "the 1st merger"

df = df.merge(transaction_summary, on = "CustomerID", how = "left")

# %%
df.head(5)
# Out:
#    CustomerID FirstName LastName                   Email   PhoneNumber  \
# 0           1      John      Doe    john.doe@example.com  123-456-7890
# 1           1      John      Doe    john.doe@example.com  123-456-7890
# 2           1      John      Doe    john.doe@example.com  123-456-7890
# 3           2      Jane    Smith  jane.smith@example.com  098-765-4321
# 4           2      Jane    Smith  jane.smith@example.com  098-765-4321
#
#      JoinDate    Status         Region  SubscriptionID   StartDate  \
# 0  10-01-2022    Active  North America             1.0  10-01-2022
# 1  10-01-2022    Active  North America            44.0  10-01-2023
# 2  10-01-2022    Active  North America           101.0  01-07-2023
# 3  15-12-2021  Inactive         Europe             2.0  15-12-2021
# 4  15-12-2021  Inactive         Europe            45.0  15-12-2022
#
#       EndDate PlanType  CustomerLifetime
# 0  09-01-2023   Annual               NaN
# 1  09-01-2024  Monthly               NaN
# 2  30-06-2024  Monthly               NaN
# 3  14-12-2022  Monthly               NaN
# 4  14-12-2023   Annual               NaN

# %%
df["CustomerLifetime"].describe()
# Out:
# count    262.000000
# mean      -8.629771
# std      126.855170
# min     -232.000000
# 25%     -122.000000
# 50%      -37.000000
# 75%      117.000000
# max      200.000000
# Name: CustomerLifetime, dtype: float64

# %%
df["CustomerLifetime"].value_counts()
# Out:
# CustomerLifetime
#  143.0    5
# -156.0    5
#  165.0    5
# -66.0     4
#  200.0    4
#          ..
# -34.0     1
#  104.0    1
# -136.0    1
#  176.0    1
#  29.0     1
# Name: count, Length: 170, dtype: int64

# %%
df["CustomerLifetime"].unique()
# Out:
# array([  nan,  195.,   32.,  -73., -140.,  -32.,  -52.,  196., -122.,
#         -20., -153.,  200.,  -66., -156.,  158., -145.,  143.,  120.,
#        -200.,  165.,  -69.,  -99., -143.,  142., -150.,  159.,  -81.,
#        -170.,  157.,  -68.,  145.,  -93.,  198., -141.,  -35.,  -44.,
#          87., -111., -149.,   73., -102., -120.,  140.,  134.,   61.,
#        -118.,  171., -199.,   96.,  -23., -116.,  185., -133., -139.,
#        -176., -107.,   98.,   94., -124.,  -70.,  -46.,  -61.,   24.,
#         103.,   43.,  131., -119.,  189., -174., -178., -162.,   23.,
#          21.,  155.,   52.,  141.,   47., -168.,   63.,  -43.,   83.,
#        -100.,  -72.,  108., -125.,   57.,  -60.,  -78.,  -38.,   22.,
#        -232.,   41., -195.,  -71.,  153.,  -40., -105., -186.,   74.,
#         128.,   76.,  181.,  -51.,   75.,  -47., -115., -147.,   28.,
#         118., -181.,  -28., -185., -192., -177., -189.,  191., -123.,
#          89.,  -48., -106.,  -55.,   35., -180.,   37.,  169., -171.,
#        -103.,   62.,   51.,   80.,  -84., -173., -182., -132.,  135.,
#        -172.,  -21.,  121., -117.,   58.,  -45.,   55.,  -94.,  -39.,
#          86.,  127.,  111., -128., -165.,  190., -101., -188.,  132.,
#          56.,   72.,  183.,   46.,  178.,  114.,   59., -134.,   34.,
#        -167.,  194.,   36.,  -36.,  -34.,  104., -136.,  176.,   29.])

# %%
churn.head(20)
# Out:
#     ChurnID  CustomerID   ChurnDate                    Reason
# 0         1          22  02-01-2024     Poor Customer Service
# 1         2          56  06-06-2024               High Prices
# 2         3          45  10-10-2024    Product Quality Issues
# 3         4          54  12-12-2024  Lack of Product Features
# 4         5          82  14-02-2024      Competitor Offerings
# 5         6          67  15-01-2024             Inconvenience
# 6         7          17  21-01-2024        Lack of Engagement
# 7         8          33  18-01-2024        Unmet Expectations
# 8         9          91  20-01-2024           Price Increases
# 9        10          23  23-01-2024    Personal Circumstances
# 10       11          27  26-01-2024     Poor Customer Service
# 11       12          72  28-01-2024               High Prices
# 12       13          31  14-02-2024    Product Quality Issues
# 13       14          50  19-02-2024  Lack of Product Features
# 14       15         123  03-05-2024      Competitor Offerings
# 15       16         185  06-05-2024             Inconvenience
# 16       17         130  10-05-2024        Lack of Engagement
# 17       18         186  07-05-2024        Unmet Expectations
# 18       19         173  25-04-2024           Price Increases
# 19       20          25  24-01-2024    Personal Circumstances

# %%
df = df.merge(churn[["CustomerID","ChurnDate"]],on = "CustomerID" , how = "left")

# %%
df.head(100)
# Out:
#     CustomerID FirstName  LastName                   Email   PhoneNumber  \
# 0            1      John       Doe    john.doe@example.com  123-456-7890
# 1            1      John       Doe    john.doe@example.com  123-456-7890
# 2            1      John       Doe    john.doe@example.com  123-456-7890
# 3            2      Jane     Smith  jane.smith@example.com  098-765-4321
# 4            2      Jane     Smith  jane.smith@example.com  098-765-4321
# ..         ...       ...       ...                     ...           ...
# 95          29      Abby    Flores      abby.f@example.com  789-012-3456
# 96          29      Abby    Flores      abby.f@example.com  789-012-3456
# 97          29      Abby    Flores      abby.f@example.com  789-012-3456
# 98          30     Brian  Gonzalez     brian.g@example.com  890-123-4567
# 99          30     Brian  Gonzalez     brian.g@example.com  890-123-4567
#
#       JoinDate    Status         Region  SubscriptionID   StartDate  \
# 0   10-01-2022    Active  North America             1.0  10-01-2022
# 1   10-01-2022    Active  North America            44.0  10-01-2023
# 2   10-01-2022    Active  North America           101.0  01-07-2023
# 3   15-12-2021  Inactive         Europe             2.0  15-12-2021
# 4   15-12-2021  Inactive         Europe            45.0  15-12-2022
# ..         ...       ...            ...             ...         ...
# 95  22-02-2021    Active         Europe            71.0  22-02-2022
# 96  22-02-2021    Active         Europe           129.0  15-07-2023
# 97  22-02-2021    Active         Europe           129.0  15-07-2023
# 98  12-06-2020  Inactive           Asia            30.0  12-06-2020
# 99  12-06-2020  Inactive           Asia            72.0  12-06-2021
#
#        EndDate PlanType  CustomerLifetime   ChurnDate
# 0   09-01-2023   Annual               NaN         NaN
# 1   09-01-2024  Monthly               NaN         NaN
# 2   30-06-2024  Monthly               NaN         NaN
# 3   14-12-2022  Monthly               NaN         NaN
# 4   14-12-2023   Annual               NaN         NaN
# ..         ...      ...               ...         ...
# 95  21-02-2023   Annual             200.0  24-01-2024
# 96  14-07-2024  Monthly             200.0  24-01-2024
# 97  14-07-2024  Monthly             200.0  24-01-2024
# 98  11-06-2021   Annual               NaN  30-01-2024
# 99  11-06-2022  Monthly               NaN  30-01-2024
#
# [100 rows x 14 columns]

# %%
#clean the data and handle the values like NaN, etc. becasue the regression works on Numeric data

df["Churned"] = df["ChurnDate"].notnull().astype(int)

# %%
df.head(100)
# Out:
#     CustomerID FirstName  LastName                   Email   PhoneNumber  \
# 0            1      John       Doe    john.doe@example.com  123-456-7890
# 1            1      John       Doe    john.doe@example.com  123-456-7890
# 2            1      John       Doe    john.doe@example.com  123-456-7890
# 3            2      Jane     Smith  jane.smith@example.com  098-765-4321
# 4            2      Jane     Smith  jane.smith@example.com  098-765-4321
# ..         ...       ...       ...                     ...           ...
# 95          29      Abby    Flores      abby.f@example.com  789-012-3456
# 96          29      Abby    Flores      abby.f@example.com  789-012-3456
# 97          29      Abby    Flores      abby.f@example.com  789-012-3456
# 98          30     Brian  Gonzalez     brian.g@example.com  890-123-4567
# 99          30     Brian  Gonzalez     brian.g@example.com  890-123-4567
#
#       JoinDate    Status         Region  SubscriptionID   StartDate  \
# 0   10-01-2022    Active  North America             1.0  10-01-2022
# 1   10-01-2022    Active  North America            44.0  10-01-2023
# 2   10-01-2022    Active  North America           101.0  01-07-2023
# 3   15-12-2021  Inactive         Europe             2.0  15-12-2021
# 4   15-12-2021  Inactive         Europe            45.0  15-12-2022
# ..         ...       ...            ...             ...         ...
# 95  22-02-2021    Active         Europe            71.0  22-02-2022
# 96  22-02-2021    Active         Europe           129.0  15-07-2023
# 97  22-02-2021    Active         Europe           129.0  15-07-2023
# 98  12-06-2020  Inactive           Asia            30.0  12-06-2020
# 99  12-06-2020  Inactive           Asia            72.0  12-06-2021
#
#        EndDate PlanType  CustomerLifetime   ChurnDate  Churned
# 0   09-01-2023   Annual               NaN         NaN        0
# 1   09-01-2024  Monthly               NaN         NaN        0
# 2   30-06-2024  Monthly               NaN         NaN        0
# 3   14-12-2022  Monthly               NaN         NaN        0
# 4   14-12-2023   Annual               NaN         NaN        0
# ..         ...      ...               ...         ...      ...
# 95  21-02-2023   Annual             200.0  24-01-2024        1
# 96  14-07-2024  Monthly             200.0  24-01-2024        1
# 97  14-07-2024  Monthly             200.0  24-01-2024        1
# 98  11-06-2021   Annual               NaN  30-01-2024        1
# 99  11-06-2022  Monthly               NaN  30-01-2024        1
#
# [100 rows x 15 columns]

# %%
#Clean the NaN from customerlifetime

df["CustomerLifetime"] = df["CustomerLifetime"].fillna(0)

# %%
df.head(100)
# Out:
#     CustomerID FirstName  LastName                   Email   PhoneNumber  \
# 0            1      John       Doe    john.doe@example.com  123-456-7890
# 1            1      John       Doe    john.doe@example.com  123-456-7890
# 2            1      John       Doe    john.doe@example.com  123-456-7890
# 3            2      Jane     Smith  jane.smith@example.com  098-765-4321
# 4            2      Jane     Smith  jane.smith@example.com  098-765-4321
# ..         ...       ...       ...                     ...           ...
# 95          29      Abby    Flores      abby.f@example.com  789-012-3456
# 96          29      Abby    Flores      abby.f@example.com  789-012-3456
# 97          29      Abby    Flores      abby.f@example.com  789-012-3456
# 98          30     Brian  Gonzalez     brian.g@example.com  890-123-4567
# 99          30     Brian  Gonzalez     brian.g@example.com  890-123-4567
#
#       JoinDate    Status         Region  SubscriptionID   StartDate  \
# 0   10-01-2022    Active  North America             1.0  10-01-2022
# 1   10-01-2022    Active  North America            44.0  10-01-2023
# 2   10-01-2022    Active  North America           101.0  01-07-2023
# 3   15-12-2021  Inactive         Europe             2.0  15-12-2021
# 4   15-12-2021  Inactive         Europe            45.0  15-12-2022
# ..         ...       ...            ...             ...         ...
# 95  22-02-2021    Active         Europe            71.0  22-02-2022
# 96  22-02-2021    Active         Europe           129.0  15-07-2023
# 97  22-02-2021    Active         Europe           129.0  15-07-2023
# 98  12-06-2020  Inactive           Asia            30.0  12-06-2020
# 99  12-06-2020  Inactive           Asia            72.0  12-06-2021
#
#        EndDate PlanType  CustomerLifetime   ChurnDate  Churned
# 0   09-01-2023   Annual               0.0         NaN        0
# 1   09-01-2024  Monthly               0.0         NaN        0
# 2   30-06-2024  Monthly               0.0         NaN        0
# 3   14-12-2022  Monthly               0.0         NaN        0
# 4   14-12-2023   Annual               0.0         NaN        0
# ..         ...      ...               ...         ...      ...
# 95  21-02-2023   Annual             200.0  24-01-2024        1
# 96  14-07-2024  Monthly             200.0  24-01-2024        1
# 97  14-07-2024  Monthly             200.0  24-01-2024        1
# 98  11-06-2021   Annual               0.0  30-01-2024        1
# 99  11-06-2022  Monthly               0.0  30-01-2024        1
#
# [100 rows x 15 columns]

# %%
df["IsInactive"] = (df["Status"] == "Inactive").astype(int)

# %%
df.head(100)
# Out:
#     CustomerID FirstName  LastName                   Email   PhoneNumber  \
# 0            1      John       Doe    john.doe@example.com  123-456-7890
# 1            1      John       Doe    john.doe@example.com  123-456-7890
# 2            1      John       Doe    john.doe@example.com  123-456-7890
# 3            2      Jane     Smith  jane.smith@example.com  098-765-4321
# 4            2      Jane     Smith  jane.smith@example.com  098-765-4321
# ..         ...       ...       ...                     ...           ...
# 95          29      Abby    Flores      abby.f@example.com  789-012-3456
# 96          29      Abby    Flores      abby.f@example.com  789-012-3456
# 97          29      Abby    Flores      abby.f@example.com  789-012-3456
# 98          30     Brian  Gonzalez     brian.g@example.com  890-123-4567
# 99          30     Brian  Gonzalez     brian.g@example.com  890-123-4567
#
#       JoinDate    Status         Region  SubscriptionID   StartDate  \
# 0   10-01-2022    Active  North America             1.0  10-01-2022
# 1   10-01-2022    Active  North America            44.0  10-01-2023
# 2   10-01-2022    Active  North America           101.0  01-07-2023
# 3   15-12-2021  Inactive         Europe             2.0  15-12-2021
# 4   15-12-2021  Inactive         Europe            45.0  15-12-2022
# ..         ...       ...            ...             ...         ...
# 95  22-02-2021    Active         Europe            71.0  22-02-2022
# 96  22-02-2021    Active         Europe           129.0  15-07-2023
# 97  22-02-2021    Active         Europe           129.0  15-07-2023
# 98  12-06-2020  Inactive           Asia            30.0  12-06-2020
# 99  12-06-2020  Inactive           Asia            72.0  12-06-2021
#
#        EndDate PlanType  CustomerLifetime   ChurnDate  Churned  IsInactive
# 0   09-01-2023   Annual               0.0         NaN        0           0
# 1   09-01-2024  Monthly               0.0         NaN        0           0
# 2   30-06-2024  Monthly               0.0         NaN        0           0
# 3   14-12-2022  Monthly               0.0         NaN        0           1
# 4   14-12-2023   Annual               0.0         NaN        0           1
# ..         ...      ...               ...         ...      ...         ...
# 95  21-02-2023   Annual             200.0  24-01-2024        1           0
# 96  14-07-2024  Monthly             200.0  24-01-2024        1           0
# 97  14-07-2024  Monthly             200.0  24-01-2024        1           0
# 98  11-06-2021   Annual               0.0  30-01-2024        1           1
# 99  11-06-2022  Monthly               0.0  30-01-2024        1           1
#
# [100 rows x 16 columns]

# %%
#define X and Y

X = df[["CustomerLifetime","IsInactive"]]
y = df["Churned"]

# %%
#Improvement Section: Scale the numerical data

scaler = StandardScaler()
X_scaler = scaler.fit_transform(X)

# %%
#split data for training & testing

X_train, X_test, y_train, y_test = train_test_split(X_scaler,y,test_size = 0.2, random_state = 42)

# %%
#Train the logistic regression model in the training data.

model = LogisticRegression(max_iter = 1000, C=2)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=2, max_iter=1000)

# %%
#Use the model on splited test to predict

y_pred = model.predict(X_test)

# %%
#Evalutate the Model

print("Model Evaluation\n")

print("Accuracy:", round(accuracy_score(y_test,y_pred),2))
print("Precision:", precision_score(y_test,y_pred))
print("Recall:", recall_score(y_test,y_pred))
print("F1 Score:", f1_score(y_test,y_pred))
print("--------------------------------------")
print("Confusion Matrix:", confusion_matrix(y_test,y_pred))
# Out:
# Model Evaluation
#
# Accuracy: 0.65
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# --------------------------------------
# Confusion Matrix: [[57  0]
#  [31  0]]
# C:\Users\anike\anaconda_\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#predict on new data:
new_data = pd.read_csv("Sample_Test_Data.csv")
new_data.head(4)
# Out:
#    CustomerLifetime  IsInactive
# 0               102           1
# 1               435           1
# 2               860           1
# 3               270           1

# %%
#predict using the loaded model for the new data
#X_new = new_data[["CustomerLifetime","IsInactive"]]

new_data["Predicted_Churn"] = model.predict(new_data)
new_data.head(20)
# Out:
#     CustomerLifetime  IsInactive  Predicted_Churn
# 0                102           1                0
# 1                435           1                0
# 2                860           1                0
# 3                270           1                0
# 4                106           1                0
# 5                 71           1                0
# 6                700           0                0
# 7                 20           1                0
# 8                614           0                0
# 9                121           1                0
# 10               466           1                0
# 11               214           0                0
# 12               330           1                0
# 13               458           0                0
# 14                87           1                0
# 15               372           1                0
# 16                99           0                0
# 17               871           1                0
# 18               663           0                0
# 19               130           1                0

# %%
new_data.to_csv("churn_prediction_output.csv",index = False)
